# %% [markdown]
# # Read an existing datasets

# %%
import pandas as pd

# %%
dp=pd.read_csv('sales.csv')

# %%
dp
# Out:
#      OrderedAt Date        Order No.        Customer Name  \
# 0      12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 1      12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 2      12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 3      12/1/20 16:20  STU-2143266042  O And K Super Store
# 4      12/1/20 16:20  STU-2143266042  O And K Super Store
# ...              ...             ...                  ...
# 2041  12/17/20 11:31  STU-2143281499     Emybest Minimart
# 2042  12/17/20 11:31  STU-2143281499     Emybest Minimart
# 2043  12/22/20 14:30  STU-2143285392   Ezzybest Minimarts
# 2044  12/22/20 14:30  STU-2143285392   Ezzybest Minimarts
# 2045  12/22/20 14:30  STU-2143285392   Ezzybest Minimarts
#
#                            Producer                                Product  \
# 0       Hayat Kimya Nigeria Limited                            Molfix Twin
# 1       Hayat Kimya Nigeria Limited                            Molfix Twin
# ...

# %% [markdown]
# # Read top 5 Records

# %%
dp.head(5)
# Out:
#   OrderedAt Date        Order No.        Customer Name  \
# 0   12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 1   12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 2   12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 3   12/1/20 16:20  STU-2143266042  O And K Super Store
# 4   12/1/20 16:20  STU-2143266042  O And K Super Store
#
#                       Producer      Product Category Group     Category  \
# 0  Hayat Kimya Nigeria Limited  Molfix Twin           Baby  Infant Care
# 1  Hayat Kimya Nigeria Limited  Molfix Twin           Baby  Infant Care
# 2  Hayat Kimya Nigeria Limited  Molfix Twin           Baby  Infant Care
# 3  Hayat Kimya Nigeria Limited  Molfix Twin           Baby  Infant Care
# 4  Hayat Kimya Nigeria Limited  Molfix Twin           Baby  Infant Care
#
#                                       Variant  Quantity Unit Price  \
# 0           Molfix Twin Midi(4-9 Kg) x 36 x 4       2.0   7,000.00
# ...

# %% [markdown]
# # Read bottom 5

# %%
dp.tail(5)
# Out:
#      OrderedAt Date        Order No.       Customer Name  \
# 2041  12/17/20 11:31  STU-2143281499    Emybest Minimart
# 2042  12/17/20 11:31  STU-2143281499    Emybest Minimart
# 2043  12/22/20 14:30  STU-2143285392  Ezzybest Minimarts
# 2044  12/22/20 14:30  STU-2143285392  Ezzybest Minimarts
# 2045  12/22/20 14:30  STU-2143285392  Ezzybest Minimarts
#
#                            Producer                                Product  \
# 2041           Henkel Expand Global                          WAW Detergent
# 2042           Henkel Expand Global  Nittol Antibacterial Powder Detergent
# 2043         PZ Cussons Nigeria Plc                         Canoe Bar Soap
# 2044                Eko Supreme Ltd           Good Mama Cleaning Detergent
# 2045  Extreme Manufacturing Nig Ltd                      So Easy Detergent
#
#      Category Group         Category  \
# 2041      Home Care  Household Clean
# 2042      Home Care  Household Clean
# 2043      Home Care     Fabric Clean
# ...

# %% [markdown]
# # Understand the dataset

# %%
dp.describe()
# Out:
#           Quantity
# count  2046.000000
# mean      3.415811
# std       6.727514
# min       0.250000
# 25%       1.000000
# 50%       1.000000
# 75%       3.000000
# max     100.000000

# %% [markdown]
# # Get the Info

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2046 entries, 0 to 2045
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderedAt Date   2046 non-null   object
#  1   Order No.        2046 non-null   object
#  2   Customer Name    2046 non-null   object
#  3   Producer         2046 non-null   object
#  4   Product          2046 non-null   object
#  5   Category Group   2046 non-null   object
#  6   Category         2046 non-null   object
#  7   Variant          2046 non-null   object
#  8   Quantity         2046 non-null   float64
#  9   Unit Price       2046 non-null   object
#  10  shippingStatus   2046 non-null   object
#  11  Delivery Agent   1914 non-null   object
#  12  Delivery Date    1790 non-null   object
#  13  Customer Type    2046 non-null   object
#  14  Order Channel    2046 non-null   object
# dtypes: float64(1), object(14)
# memory usage: 239.9+ KB

# %% [markdown]
# # checking the customer name coloumn

# %%
dp['Customer Name']
# Out:
# 0         Rodam Enterprises
# 1         Rodam Enterprises
# 2         Rodam Enterprises
# 3       O And K Super Store
# 4       O And K Super Store
#                ...
# 2041       Emybest Minimart
# 2042       Emybest Minimart
# 2043     Ezzybest Minimarts
# 2044     Ezzybest Minimarts
# 2045     Ezzybest Minimarts
# Name: Customer Name, Length: 2046, dtype: object

# %% [markdown]
# # list all coloumns

# %%
dp.columns
# Out:
# Index(['OrderedAt Date ', 'Order No.', 'Customer Name', 'Producer', 'Product',
#        'Category Group', 'Category', 'Variant', 'Quantity', 'Unit Price',
#        'shippingStatus', 'Delivery Agent', 'Delivery Date', 'Customer Type',
#        'Order Channel'],
#       dtype='object')

# %% [markdown]
# # created another dataframe

# %%
dp2=dp

# %%
dp2.head(5)
# Out:
#   OrderedAt Date        Order No.        Customer Name  \
# 0   12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 1   12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 2   12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 3   12/1/20 16:20  STU-2143266042  O And K Super Store
# 4   12/1/20 16:20  STU-2143266042  O And K Super Store
#
#                       Producer      Product Category Group     Category  \
# 0  Hayat Kimya Nigeria Limited  Molfix Twin           Baby  Infant Care
# 1  Hayat Kimya Nigeria Limited  Molfix Twin           Baby  Infant Care
# 2  Hayat Kimya Nigeria Limited  Molfix Twin           Baby  Infant Care
# 3  Hayat Kimya Nigeria Limited  Molfix Twin           Baby  Infant Care
# 4  Hayat Kimya Nigeria Limited  Molfix Twin           Baby  Infant Care
#
#                                       Variant  Quantity Unit Price  \
# 0           Molfix Twin Midi(4-9 Kg) x 36 x 4       2.0   7,000.00
# ...

# %%
dp2=dp2.rename(columns={'Category Group':'catgroup','Delivery Agent':'DA','':'OrderAt Date''OAD'})

# %%
dp2.head(5)
# Out:
#   OrderedAt Date        Order No.        Customer Name  \
# 0   12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 1   12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 2   12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 3   12/1/20 16:20  STU-2143266042  O And K Super Store
# 4   12/1/20 16:20  STU-2143266042  O And K Super Store
#
#                       Producer      Product catgroup     Category  \
# 0  Hayat Kimya Nigeria Limited  Molfix Twin     Baby  Infant Care
# 1  Hayat Kimya Nigeria Limited  Molfix Twin     Baby  Infant Care
# 2  Hayat Kimya Nigeria Limited  Molfix Twin     Baby  Infant Care
# 3  Hayat Kimya Nigeria Limited  Molfix Twin     Baby  Infant Care
# 4  Hayat Kimya Nigeria Limited  Molfix Twin     Baby  Infant Care
#
#                                       Variant  Quantity Unit Price  \
# 0           Molfix Twin Midi(4-9 Kg) x 36 x 4       2.0   7,000.00
# 1   Molfix Twin Mini(3-6 kg) by 40, pack of 4       1.0   7,000.00
# ...

# %% [markdown]
# # add new columns

# %%
dp2['Unit P - Var'] = dp2['Unit Price'] + dp2['Variant']

# %%
dp2.head(5)
# Out:
#   OrderedAt Date        Order No.        Customer Name  \
# 0   12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 1   12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 2   12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 3   12/1/20 16:20  STU-2143266042  O And K Super Store
# 4   12/1/20 16:20  STU-2143266042  O And K Super Store
#
#                       Producer      Product catgroup     Category  \
# 0  Hayat Kimya Nigeria Limited  Molfix Twin     Baby  Infant Care
# 1  Hayat Kimya Nigeria Limited  Molfix Twin     Baby  Infant Care
# 2  Hayat Kimya Nigeria Limited  Molfix Twin     Baby  Infant Care
# 3  Hayat Kimya Nigeria Limited  Molfix Twin     Baby  Infant Care
# 4  Hayat Kimya Nigeria Limited  Molfix Twin     Baby  Infant Care
#
#                                       Variant  Quantity Unit Price  \
# 0           Molfix Twin Midi(4-9 Kg) x 36 x 4       2.0   7,000.00
# 1   Molfix Twin Mini(3-6 kg) by 40, pack of 4       1.0   7,000.00
# ...

# %%
dp2.drop(['Unit P - Var'], axis=1)
# Out:
#      OrderedAt Date        Order No.        Customer Name  \
# 0      12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 1      12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 2      12/1/20 17:37  STU-2143266178    Rodam Enterprises
# 3      12/1/20 16:20  STU-2143266042  O And K Super Store
# 4      12/1/20 16:20  STU-2143266042  O And K Super Store
# ...              ...             ...                  ...
# 2041  12/17/20 11:31  STU-2143281499     Emybest Minimart
# 2042  12/17/20 11:31  STU-2143281499     Emybest Minimart
# 2043  12/22/20 14:30  STU-2143285392   Ezzybest Minimarts
# 2044  12/22/20 14:30  STU-2143285392   Ezzybest Minimarts
# 2045  12/22/20 14:30  STU-2143285392   Ezzybest Minimarts
#
#                            Producer                                Product  \
# 0       Hayat Kimya Nigeria Limited                            Molfix Twin
# 1       Hayat Kimya Nigeria Limited                            Molfix Twin
# ...

# %% [markdown]
# # Set Index

# %%
dp2 = dp2.set_index('DA')

# %%
dp2.head()
# Out:
#                  OrderedAt Date        Order No.        Customer Name  \
# DA
# Maryjane Joel      12/1/20 17:37  STU-2143266178    Rodam Enterprises
# Maryjane Joel      12/1/20 17:37  STU-2143266178    Rodam Enterprises
# Maryjane Joel      12/1/20 17:37  STU-2143266178    Rodam Enterprises
# Ralia Okwuchukwu   12/1/20 16:20  STU-2143266042  O And K Super Store
# Ralia Okwuchukwu   12/1/20 16:20  STU-2143266042  O And K Super Store
#
#                                      Producer      Product catgroup  \
# DA
# Maryjane Joel     Hayat Kimya Nigeria Limited  Molfix Twin     Baby
# Maryjane Joel     Hayat Kimya Nigeria Limited  Molfix Twin     Baby
# Maryjane Joel     Hayat Kimya Nigeria Limited  Molfix Twin     Baby
# Ralia Okwuchukwu  Hayat Kimya Nigeria Limited  Molfix Twin     Baby
# Ralia Okwuchukwu  Hayat Kimya Nigeria Limited  Molfix Twin     Baby
#
#                      Category                                     Variant  \
# DA
# ...

# %% [markdown]
# # Delete Row

# %%
dp2.drop('Ralia Okwuchukwu', axis=0).head()
# Out:
#                OrderedAt Date        Order No.      Customer Name  \
# DA
# Maryjane Joel    12/1/20 17:37  STU-2143266178  Rodam Enterprises
# Maryjane Joel    12/1/20 17:37  STU-2143266178  Rodam Enterprises
# Maryjane Joel    12/1/20 17:37  STU-2143266178  Rodam Enterprises
# Adaeze gabriel   12/1/20 14:59  STU-2143265849     Jovik Minimart
# Adaeze gabriel   12/1/20 14:59  STU-2143265849     Jovik Minimart
#
#                                       Producer                        Product  \
# DA
# Maryjane Joel      Hayat Kimya Nigeria Limited                    Molfix Twin
# Maryjane Joel      Hayat Kimya Nigeria Limited                    Molfix Twin
# Maryjane Joel      Hayat Kimya Nigeria Limited                    Molfix Twin
# Adaeze gabriel  FrieslandCampina WAMCO Nigeria  My Boy Eldorin Infant Formula
# Adaeze gabriel              Nestle Nigeria Plc             NAN Infant Formula
#
#                catgroup     Category  \
# DA
# Maryjane Joel      Baby  Infant Care
# ...

# %% [markdown]
# # Conditional Filtering

# %%
dp2[dp2['Customer Name'] =='Mary Joel']
# Out:
# Empty DataFrame
# Columns: [OrderedAt Date , Order No., Customer Name, Producer, Product, catgroup, Category, Variant, Quantity, Unit Price, shippingStatus, Delivery Date, Customer Type, Order Channel, Unit P - Var]
# Index: []

# %%
dp2[dp2['Category'] == 'Mary Joel']
# Out:
# Empty DataFrame
# Columns: [OrderedAt Date , Order No., Customer Name, Producer, Product, catgroup, Category, Variant, Quantity, Unit Price, shippingStatus, Delivery Date, Customer Type, Order Channel, Unit P - Var]
# Index: []

# %%
dp2[dp2['Category'] == 'Mary Joel'].count()
# Out:
# OrderedAt Date     0
# Order No.          0
# Customer Name      0
# Producer           0
# Product            0
# catgroup           0
# Category           0
# Variant            0
# Quantity           0
# Unit Price         0
# shippingStatus     0
# Delivery Date      0
# Customer Type      0
# Order Channel      0
# Unit P - Var       0
# dtype: int64
